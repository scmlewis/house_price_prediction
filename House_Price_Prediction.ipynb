# %% [markdown]
# # Step 1: EDA

# %%
# %% [markdown]
# # ISOM5610: Introduction to Business Analytics
# ## Step 1: Data Understanding and Exploratory Data Analysis (EDA)
# This notebook performs EDA on the Ames house price dataset to understand its structure, identify patterns, and detect issues (e.g., missing values, outliers, multicollinearity). Outputs are displayed inline for review.

# %% [markdown]
# ### Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor
from IPython.display import display

# Set up plotting style
try:
    plt.style.use('ggplot')  # Use 'ggplot' style for clean aesthetics
except OSError:
    print("Warning: 'ggplot' style not found. Using default Matplotlib style.")
sns.set(font_scale=1.2)

# %% [markdown]
# ### Step 1.1: Load the Dataset
def load_data(file_path='data/Ames.csv'):
    try:
        df = pd.read_csv(file_path)
        print(f"Dataset loaded with {df.shape[0]} rows and {df.shape[1]} columns.")
        return df
    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found. Please ensure 'Ames.csv' is in the 'data' subfolder.")
        raise

# Load dataset
df = load_data()

# %% [markdown]
# ### Step 1.2: Summarize Data
def summarize_data(df):
    # Descriptive statistics for numerical variables
    numerical_summary = df.select_dtypes(include=['int64', 'float64']).describe()
    print("\nDescriptive Statistics for Numerical Variables:")
    display(numerical_summary)
    
    # Summary for categorical variables
    categorical_cols = df.select_dtypes(include=['object']).columns
    print("\nCategorical Variables Summary:")
    for col in categorical_cols:
        print(f"{col}: {df[col].nunique()} unique values, Mode: {df[col].mode()[0]}")
    
    return numerical_summary, categorical_cols

# Summarize data
numerical_summary, categorical_cols = summarize_data(df)

# %% [markdown]
# ### Step 1.3: Visualize Distributions
def plot_distributions(df, key_numerical=['SalePrice', 'GrLivArea', 'LotArea', 'TotalBsmtSF'], 
                       key_categorical=['Neighborhood', 'OverallQual']):
    # Numerical variables: Histograms and Boxplots
    for col in key_numerical:
        plt.figure(figsize=(12, 5))
        
        # Histogram
        plt.subplot(1, 2, 1)
        sns.histplot(df[col], kde=True)
        plt.title(f'Distribution of {col}')
        plt.xlabel(col)
        
        # Boxplot
        plt.subplot(1, 2, 2)
        sns.boxplot(y=df[col])
        plt.title(f'Boxplot of {col}')
        
        plt.tight_layout()
        plt.show()
    
    # Categorical variables: Boxplots of SalePrice
    for col in key_categorical:
        plt.figure(figsize=(10, 6))
        sns.boxplot(x=col, y='SalePrice', data=df)
        plt.title(f'SalePrice by {col}')
        plt.xticks(rotation=45)
        plt.show()

# Plot distributions
plot_distributions(df)

# %% [markdown]
# ### Step 1.4: Explore Relationships
def explore_relationships(df, predictors=['GrLivArea', 'LotArea', 'TotalBsmtSF']):
    # Scatterplots
    for col in predictors:
        plt.figure(figsize=(8, 6))
        sns.scatterplot(x=df[col], y=df['SalePrice'])
        plt.title(f'SalePrice vs {col}')
        plt.xlabel(col)
        plt.ylabel('SalePrice')
        plt.show()
    
    # Correlation matrix
    numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
    corr_matrix = df[numerical_cols].corr()
    plt.figure(figsize=(12, 10))
    sns.heatmap(corr_matrix, annot=False, cmap='coolwarm', center=0)
    plt.title('Correlation Matrix')
    plt.show()
    
    # Top correlations with SalePrice
    saleprice_corr = corr_matrix['SalePrice'].sort_values(ascending=False)
    print("\nTop Correlations with SalePrice:")
    display(saleprice_corr.head(10))
    return corr_matrix

# Explore relationships
corr_matrix = explore_relationships(df)

# %% [markdown]
# ### Step 1.5: Check for Multicollinearity
def check_multicollinearity(df, predictors=['GrLivArea', 'LotArea', 'TotalBsmtSF', 'OverallQual', 
                                            'YearBuilt', '1stFlrSF']):
    # Prepare data for VIF
    X = df[predictors].fillna(df[predictors].median())
    X = (X - X.mean()) / X.std()  # Standardize to avoid scale issues
    vif_data = pd.DataFrame()
    vif_data['Predictor'] = predictors
    vif_data['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    print("\nVariance Inflation Factors:")
    display(vif_data)
    return vif_data

# Check multicollinearity
vif_data = check_multicollinearity(df)

# %% [markdown]
# ### Step 1.6: Assess Missing Values
def assess_missing_values(df):
    missing = df.isnull().sum()
    missing_percent = (missing / len(df)) * 100
    missing_df = pd.DataFrame({'Missing Count': missing, 'Missing Percent': missing_percent})
    missing_df = missing_df[missing_df['Missing Count'] > 0].sort_values(by='Missing Count', ascending=False)
    print("\nMissing Values:")
    display(missing_df)
    return missing_df

# Assess missing values
missing_df = assess_missing_values(df)

# %% [markdown]
# ### Step 1.7: Detect Outliers
def detect_outliers(df, columns=['SalePrice', 'GrLivArea', 'LotArea']):
    outliers = {}
    for col in columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        outlier_count = ((df[col] < lower_bound) | (df[col] > upper_bound)).sum()
        outliers[col] = outlier_count
        print(f"\nOutliers in {col}: {outlier_count}")
    return outliers

# Detect outliers
outliers = detect_outliers(df)
# Out:
# Dataset loaded with 1460 rows and 81 columns.
#
# Descriptive Statistics for Numerical Variables:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000  ...
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 38 columns]
# Categorical Variables Summary:
# MSZoning: 5 unique values, Mode: RL
# Street: 2 unique values, Mode: Pave
# Alley: 2 unique values, Mode: Grvl
# LotShape: 4 unique values, Mode: Reg
# LandContour: 4 unique values, Mode: Lvl
# Utilities: 2 unique values, Mode: AllPub
# LotConfig: 5 unique values, Mode: Inside
# LandSlope: 3 unique values, Mode: Gtl
# Neighborhood: 25 unique values, Mode: NAmes
# Condition1: 9 unique values, Mode: Norm
# Condition2: 8 unique values, Mode: Norm
# BldgType: 5 unique values, Mode: 1Fam
# HouseStyle: 8 unique values, Mode: 1Story
# RoofStyle: 6 unique values, Mode: Gable
# RoofMatl: 8 unique values, Mode: CompShg
# Exterior1st: 15 unique values, Mode: VinylSd
# Exterior2nd: 16 unique values, Mode: VinylSd
# MasVnrType: 3 unique values, Mode: BrkFace
# ExterQual: 4 unique values, Mode: TA
# ExterCond: 5 unique values, Mode: TA
# Foundation: 6 unique values, Mode: PConc
# BsmtQual: 4 unique values, Mode: TA
# BsmtCond: 4 unique values, Mode: TA
# BsmtExposure: 4 unique values, Mode: No
# BsmtFinType1: 6 unique values, Mode: Unf
# BsmtFinType2: 6 unique values, Mode: Unf
# Heating: 6 unique values, Mode: GasA
# HeatingQC: 5 unique values, Mode: Ex
# CentralAir: 2 unique values, Mode: Y
# Electrical: 5 unique values, Mode: SBrkr
# KitchenQual: 4 unique values, Mode: TA
# Functional: 7 unique values, Mode: Typ
# FireplaceQu: 5 unique values, Mode: Gd
# GarageType: 6 unique values, Mode: Attchd
# GarageFinish: 3 unique values, Mode: Unf
# GarageQual: 5 unique values, Mode: TA
# GarageCond: 5 unique values, Mode: TA
# PavedDrive: 3 unique values, Mode: Y
# PoolQC: 3 unique values, Mode: Gd
# Fence: 4 unique values, Mode: MnPrv
# MiscFeature: 4 unique values, Mode: Shed
# SaleType: 9 unique values, Mode: WD
# SaleCondition: 6 unique values, Mode: Normal
# Top Correlations with SalePrice:
# SalePrice       1.000000
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# Name: SalePrice, dtype: float64
# Variance Inflation Factors:
#      Predictor       VIF
# 0    GrLivArea  2.034557
# 1      LotArea  1.135221
# 2  TotalBsmtSF  3.520591
# 3  OverallQual  2.475310
# 4    YearBuilt  1.608119
# 5     1stFlrSF  3.639910
# Missing Values:
#               Missing Count  Missing Percent
# PoolQC                 1453        99.520548
# MiscFeature            1406        96.301370
# Alley                  1369        93.767123
# Fence                  1179        80.753425
# MasVnrType              872        59.726027
# FireplaceQu             690        47.260274
# LotFrontage             259        17.739726
# GarageType               81         5.547945
# GarageYrBlt              81         5.547945
# GarageFinish             81         5.547945
# GarageQual               81         5.547945
# GarageCond               81         5.547945
# BsmtFinType2             38         2.602740
# BsmtExposure             38         2.602740
# BsmtFinType1             37         2.534247
# BsmtCond                 37         2.534247
# BsmtQual                 37         2.534247
# MasVnrArea                8         0.547945
# Electrical                1         0.068493
# Outliers in SalePrice: 61
#
# Outliers in GrLivArea: 31
#
# Outliers in LotArea: 69
